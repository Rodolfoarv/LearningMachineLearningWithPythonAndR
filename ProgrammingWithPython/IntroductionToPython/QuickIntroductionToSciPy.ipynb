# %%
# Scipy provides basic functions to work with images

from scipy.misc import imread, imsave, imresize, imshow
img = imread('images/dog.jpg')
print(img.dtype, img.shape)

# We may tint the image by scaling each of the color channels by a different scalar constant

img_tinted = img * [1,0.5,0.5]

# Resize the image

img_tinted = imresize(img_tinted, (300,300))
imsave('images/dog_tinted.jpg', img_tinted)
imshow(img_tinted)
# Out:
# uint8 (900, 900, 3)

# %%
# MATLAB FILES 

# Functions scipy.io.loadmat and scipy.io.savemat allow us to read and write MATLAB files.

#Scipy may be useful to compute distances between sets of points

import numpy as np
from scipy.spatial.distance import pdist, squareform

x = np.array([[0,1], [1,0], [2,0]])
print(x)

#Compute the Euclidean distance between all rows of X 
d = squareform(pdist(x, 'euclidean'))
print(d)
# Out:
# [[0 1]
#  [1 0]
#  [2 0]]
# [[ 0.          1.41421356  2.23606798]
#  [ 1.41421356  0.          1.        ]
#  [ 2.23606798  1.          0.        ]]

# %%
# PLOTTING

import matplotlib.pyplot as plt

x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])
plt.show()

#We may plot several things in the same figure using the subplot function

plt.subplot(2,1,1)

#Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

#Set the second subplot as active and do the modifications
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

plt.show()

# %%
#It is possible to use the imshow function to show images

img = imread('images/dog.jpg')
img_tinted = img * [1,0.5,0.5]

# Show the original image

plt.subplot(1,2,1)
plt.imshow(img)

# Show the tinted image

plt.subplot(1,2,2)
plt.imshow(np.uint8(img_tinted))
plt.show()
